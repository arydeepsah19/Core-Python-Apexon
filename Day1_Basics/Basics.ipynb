# %% [markdown]
# # Day 1 - Core Python Basics
# ## Topics Covered:
# - Interpreter
# - Compilation
# - Whitespace
# - Line Termination

# %%
x=10
if x>5:
print("X is greater") #error due to indentation
# Out:
#   Cell In [1], line 3
#     print("X is greater")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
x=10
if x>5:
    print("X is greater")
    print("Hi everyone")
print("Exit") # c is outside the if
# Out:
# X is greater
# Hi everyone
# Exit

# %%
# single line if statement

a = 7
b = 5
if(a>b) : print("Yes")
# Out:
# Yes

# %%
# line continuation error
total = 10+20+30+
40+50
print(total) # without backlash it show syntax error
# Out:
#   Cell In [9], line 2
#     total = 10+20+30+
#                      ^
# SyntaxError: invalid syntax

# %%
# you can continue the line with backlash

total = 10+20+30+\
40+50
print(total)
# Out:
# 150

# %%
#use brackets for multiple lines

number = [1,2,3,4
,5,6,7]
print(number)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
# neasted if with indentation

a = 10
if a>5:
    print("A")
    if a>8:
        print("B")
    print("C") # ci outside the 2nd if but inside the 1st if
# Out:
# A
# B
# C

# %%
# Multi-Line string can be done by """ """

text = """hello 
hii all is good
my name is Arya"""
print(text)
# Out:
# hello
# hii all is good
# my name is Arya

# %%
 # it escapes the newline inside the string
txt= "hello \
 Bacho"
print(txt)
# Out:
# hello Bacho

# %%
a = 20,b =10  # you can't declare two varibel in one line
print(b)
# Out:
#   Cell In [25], line 1
#     a = 20,b =10
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a = 20;b =10  # you can declare two varibel in one line by ;
print(b)
# Out:
# 10
