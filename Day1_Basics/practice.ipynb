# %% [markdown]
# # print you name and college

# %%
name = 'Arydeep Sah'
college = 'Chitkara University'
company = 'Apexon'

print(name)
print(college)
print(company)
# Out:
# Arydeep Sah
# Chitkara University
# Apexon

# %% [markdown]
# # take input and print double value

# %%
st = input('Enter the number: ')
num = int(st)
num = num*2
print("Doubel of",st,"is",num)
# Out:
# Enter the number: 4
# Doubel of 4 is 8

# %% [markdown]
# # swap two number without third variable

# %%
a = 10
b = 20

print("Before swap :-")
print("a is :-",a); print("b is :-",b)

a=a+b
b=a-b
a=a-b

print("After Swap :-")
print("a is :-",a); print("b is :-",b)
# Out:
# Before swap :-
# a is :- 10
# b is :- 20
# After Swap :-
# a is :- 20
# b is :- 10

# %% [markdown]
# # check if number is even or odd

# %%
st = input("Enter number: ")
num = int(st);

if num%2==0:
    print(num, "is even number.")
else:
    print(num, "is odd number.")
# Out:
# Enter number: 15
# 15 is odd number.

# %% [markdown]
# # divide two number (handle division by zero)

# %%
num = float(input("Enter first number: "))
dem = float(input("Enter second number: "))

if dem!=0:
    print("Division result is :-", num/dem);
else:
    print("!! Error :- Cannot divide by zero !!")
# Out:
# Enter first number: 50
# Enter second number: 0
# !! Error :- Cannot divide by zero !!

# %% [markdown]
# # power calculation

# %%
base = int(input("Enter base number: "))
power = int(input("Enter power number: "))

print("Result is :-", base**power)
# Out:
# Enter base number: 5
# Enter power number: 2
# Result is :- 25

# %% [markdown]
# # convert celsius to Fahrenheit

# %%
celsius = int(input("Enter the celsius temperature"))

f = (celsius*9/5) +32;
print("Temperature i")
